# %% [markdown]
# <a href="https://colab.research.google.com/github/amoreano/PROYECTO1_CD/blob/main/visualizations_course_1_seaborn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Visualizations with seaborn
#
# Seaborn is a Python data visualization library based on matplotlib. It provides a high-level interface for drawing attractive and informative statistical graphics.
#
# **Seaborn helps you explore and understand your data**. Its plotting functions operate on dataframes and arrays containing whole datasets and internally perform the necessary semantic mapping and statistical aggregation to produce informative plots. Its dataset-oriented, declarative API lets you focus on what the different elements of your plots mean, rather than on the details of how to draw them

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
from google.colab import drive 
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# ## importing data StudentPerformance

# %%
df = pd.read_csv('/content/gdrive/MyDrive/Data Project/Data Project/04. Teaching/000. Teaching Lessons/03. Lesson Plans/01. python basics/04. visualizations/02. seaborn_intro1/StudentsPerformance.csv')

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df.shape
# Out:
# (1000, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %% [markdown]
# ## EDA

# %%
df.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
df.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
categories = ['gender', 'race/ethnicity', 'parental level of education', 'lunch',
       'test preparation course']
for category in categories:
  print(df[category].value_counts())
  print('♠' * 30)
# Out:
# female    518
# male      482
# Name: gender, dtype: int64
# ♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠
# group C    319
# group D    262
# group B    190
# group E    140
# group A     89
# Name: race/ethnicity, dtype: int64
# ♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠
# some college          226
# associate's degree    222
# high school           196
# some high school      179
# bachelor's degree     118
# master's degree        59
# Name: parental level of education, dtype: int64
# ♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠
# standard        645
# free/reduced    355
# Name: lunch, dtype: int64
# ♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠
# none         642
# completed    358
# Name: test preparation course, dtype: int64
# ♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠

# %% [markdown]
# ## Univariate plots

# %% [markdown]
# ### barplot
#
# https://seaborn.pydata.org/generated/seaborn.barplot.html#seaborn.barplot

# %%
sns.barplot(data=df)

# %%
sns.barplot(data=df,
            palette='colorblind',
            ci='sd')

# %%
sns.barplot(data=df,
            palette='colorblind',
            ci=90,
            orient='h')

# %%
# sns.barplot(data=df,
#             palette='colorblind',
#             # ci=50,
#             orient='h',
#             units='score')

# %%
sns.barplot(data=df, y='math score',
            x='gender',
            palette='bright')

# %%
sns.barplot(data=df, y='math score',
            x='parental level of education',
            palette='bright')
plt.xticks(rotation=50)
plt.show()

# %% [markdown]
# ### lineplot
#
# https://seaborn.pydata.org/generated/seaborn.lineplot.html#seaborn.lineplot

# %%
sns.lineplot(data=df, x='reading score', y='math score')
plt.show()

# %%
sns.lineplot(data=df, x='reading score', y='math score',
             ci=99)
plt.show()

# %%
sns.lineplot(data=df, x='reading score', y='math score',
             ci='sd',
             hue='writing score',
             legend='auto')
plt.show()

# %%
sns.lineplot(data=df, x='reading score', y='math score',
             ci='sd',
             hue='parental level of education',
             legend='auto')
plt.show()

# %%
sns.lineplot(data=df, x='reading score', y='math score',
             ci='sd',
             hue='gender',
             legend='auto')
plt.show()

# %% [markdown]
# ### histplot

# %%
df.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
sns.histplot(data=df, x='reading score',
             stat='count')

# %%
sns.histplot(data=df, x='reading score',
             stat='probability')

# %%
sns.histplot(data=df, x='reading score',
             stat='probability',
             hue='gender')

# %% [markdown]
# ### kdeplot
# https://seaborn.pydata.org/generated/seaborn.kdeplot.html#seaborn.kdeplot

# %%
sns.kdeplot(data=df, x='reading score')

# %%
sns.kdeplot(data=df, x='reading score', bw=.15)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.15 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)

# %%
sns.kdeplot(data=df, x='reading score', bw=.15, hue='gender')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.15 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ### boxplot
#
# https://seaborn.pydata.org/generated/seaborn.boxplot.html#seaborn.boxplot

# %%
sns.boxplot(data=df, x='writing score')

# %%
sns.boxplot(data=df, x='writing score',
            y='race/ethnicity')

# %%
sns.boxplot(data=df, x='reading score',
            y='race/ethnicity')

# %% [markdown]
# ### violin plot
#
# https://seaborn.pydata.org/generated/seaborn.violinplot.html#seaborn.violinplot

# %%
df.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
sns.violinplot(data=df, y='reading score')

# %%
sns.violinplot(data=df, y='reading score', x='lunch', hue='gender', split=True) #

# %%
sns.violinplot(data=df, y='reading score', x='gender',
               hue='lunch',
               split=True,
               inner='quartile')

# %%
sns.violinplot(data=df, y='reading score', x='gender',
               hue='lunch',
               split=True,
               inner='quartile',
               bw=.2)

# %%
sns.violinplot(data=df, y='reading score', x='gender',
               hue='lunch',
               split=True,
               inner='stick',
               bw=.1)

# %% [markdown]
# ### boxen plot
#
# https://seaborn.pydata.org/generated/seaborn.boxenplot.html#seaborn.boxenplot

# %%
df.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
sns.boxenplot(data=df,x='reading score')
plt.show()

# %%
sns.boxenplot(data=df,x='writing score')
plt.show()

# %%
sns.boxenplot(data=df,x='writing score',
              showfliers=False)
plt.show()

# %%
sns.boxenplot(data=df,x='writing score',
              showfliers=True,
              y='gender')
plt.show()

# %%
sns.boxenplot(data=df,x='writing score',
              showfliers=False,
              y='race/ethnicity')
plt.show()

# %% [markdown]
# ### count plot
#
# https://seaborn.pydata.org/generated/seaborn.countplot.html#seaborn.countplot

# %%
sns.countplot(data=df, x='gender')

# %%
sns.countplot(data=df, x='race/ethnicity')

# %%
sns.countplot(data=df, x='lunch')

# %% [markdown]
# ### swarm plot
#
# https://seaborn.pydata.org/generated/seaborn.swarmplot.html#seaborn.swarmplot

# %%
sns.swarmplot(data=df, x='reading score',
              y='gender')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 19.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 17.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.swarmplot(data=df, x='reading score',
              y='gender',
              size=10)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 65.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 64.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.swarmplot(data=df, x='gender',
              y='reading score',
              size=4)
plt.show()

# %% [markdown]
# ## Bivariate plots

# %% [markdown]
# ### joint plot
#
# https://seaborn.pydata.org/generated/seaborn.jointplot.html#seaborn.jointplot

# %%
df.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
sns.jointplot(data=df, x='math score', y='writing score')

# %%
sns.jointplot(data=df, x='math score',
              y='writing score',
              kind='hex')

# %%
sns.jointplot(data=df, x='math score',
              y='writing score',
              kind='kde')

# %%
sns.jointplot(data=df, x='math score',
              y='writing score',
              hue='gender',
              kind='kde')

# %%
sns.jointplot(data=df, x='math score',
              y='writing score',
              # hue='gender',
              kind='hex',
              joint_kws={'bins':9},
              marginal_kws={'bins':500}
              )

# %%
sns.jointplot(data=df, x='math score',
              y='writing score',
              # hue='gender',
              kind='hex',
              joint_kws={'color':'red'},
              marginal_kws={'bins':10, 'fill':False}
              )

# %% [markdown]
# ### heatmap

# %%
sns.heatmap(df.corr())

# %%
sns.heatmap(df.corr(), annot=True, cmap='crest')

# %% [markdown]
# ### pairplot
#
# https://seaborn.pydata.org/generated/seaborn.pairplot.html

# %%
sns.pairplot(df)

# %%
sns.pairplot(df,
             kind='hist')

# %%
sns.pairplot(df,
             kind='hist',
             corner=True)

# %%
sns.pairplot(df,
             kind='hist',
             corner=True,
             diag_kind='kde')

# %%
sns.pairplot(df,
             kind='reg',
             corner=True,
             hue='gender',
             diag_kind='kde')

# %% [markdown]
# ## PairGrid

# %%
# g = sns.pairplot(df,
#              kind='hist',
#             #  corner=True,
#              hue='gender',
#              diag_kind='hist')
g = sns.PairGrid(df, hue='gender')
g.map_diag(sns.histplot)
g.map_upper(sns.kdeplot, alpha=.7)
g.map_lower(sns.regplot)

# %% [markdown]
# ## FacetGrid

# %%
g =sns.FacetGrid(data=df, row='lunch', col='test preparation course')
g.map(sns.histplot, 'math score')

# %%
g =sns.FacetGrid(data=df, row='lunch', col='test preparation course')
g.map(sns.distplot, 'math score')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
g =sns.FacetGrid(data=df, row='lunch', col='gender')
g.map(sns.violinplot, 'writing score')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:670: UserWarning: Using the violinplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
g =sns.FacetGrid(data=df, row='lunch', col='test preparation course', hue='gender')
g.map(sns.distplot, 'math score')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# ### lmplot
#
# https://seaborn.pydata.org/generated/seaborn.lmplot.html#seaborn.lmplot

# %%
sns.lmplot(data=df, x='math score', y='writing score')

# %%
sns.lmplot(data=df, x='math score', y='writing score', order=2)

# %%
sns.lmplot(data=df, x='math score', y='reading score', order=2, col='gender', hue='lunch' )

# %% [markdown]
# ### displot

# %%
sns.displot(data=df, x='math score')

# %%
sns.displot(data=df, x='math score', kind='kde')

# %%
sns.displot(data=df, x='math score', y='reading score',col='gender', hue='lunch' )

# %% [markdown]
# ### catplot

# %%
sns.catplot(data=df, x='math score', y='lunch')

# %%
sns.catplot(data=df, x='math score', y='lunch', kind='box')

# %%
sns.catplot(data=df, x='math score', y='lunch', col='gender', kind='box')

# %% [markdown]
# # color palette

# %% [markdown]
# ## diverging palette

# %%
sns.diverging_palette(210, 25, l=65, center="light",
                                         as_cmap=True, n=9)

# %%
pal = sns.diverging_palette(210, 25, l=65, center="light",
                                         as_cmap=True, n=9)

# %%
sns.heatmap(df.corr(), annot=True, cmap=pal)

# %% [markdown]
# ## Dark palette

# %%
pal = sns.dark_palette((260, 75, 60), input='husl')

# %%
sns.heatmap(df.corr(), annot=True, cmap=pal)

# %% [markdown]
# ## Light palette

# %%
pal = sns.light_palette((260, 75, 60), input="husl")

# %%
sns.heatmap(df.corr(), annot=True, cmap=pal)
