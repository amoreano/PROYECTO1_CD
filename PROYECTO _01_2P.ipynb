# %% [markdown]
# Alumno: ANDRES MOREANO VARGAS

# %%
import pandas as pd
import numpy as np

# %%
encabezado=["Ingresos mensuales"]
datos={"Cliente1":[8000],
       "Cliente2":[6000],
       "Cliente3":[3000],
       "Cliente4":[4000]}
clientes=pd.DataFrame(datos,index=encabezado)
clientes
# Out:
#                     Cliente1  Cliente2  Cliente3  Cliente4
# Ingresos mensuales      8000      6000      3000      4000

# %%
clientes.T
# Out:
#           Ingresos mensuales
# Cliente1                8000
# Cliente2                6000
# Cliente3                3000
# Cliente4                4000

# %%
clientes.min().min()
# Out:
# 3000

# %%
clientes.max().max()
# Out:
# 8000

# %%
clientes.mean().mean()
# Out:
# 5250.0
