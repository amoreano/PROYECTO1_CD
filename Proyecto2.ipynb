# %% [markdown]
# <a href="https://colab.research.google.com/github/amoreano/PROYECTO1_CD/blob/main/Proyecto2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-228b46d6-e19d-4b8f-99f6-ef9ee20a1989" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-228b46d6-e19d-4b8f-99f6-ef9ee20a1989">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving autos.csv to autos.csv
# ...

# %%
df=pd.read_csv("/content/autos.csv")
df.head(50)
# Out:
#     Millas_Por_Galon  Cilindros Pais_Origen  Peso_En_Libras  Desplazamiento  \
# 0               18.0          8         USA            3504           307.0
# 1               15.0          8         USA            3693           350.0
# 2               18.0          8         USA            3436           318.0
# 3               16.0          8         USA            3433           304.0
# 4               17.0          8         USA            3449           302.0
# 5               15.0          8         USA            4341           429.0
# 6               14.0          8         USA            4354           454.0
# 7               14.0          8         USA            4312           440.0
# 8               14.0          8         USA            4425           455.0
# 9               15.0          8         USA            3850           390.0
# 10               NaN          4      Europe            3090           133.0
# ...

# %%
Pais_Origen_={"USA":1,"Europe":2, "Japan":3}
df["Pais_Origen"]=df["Pais_Origen"].map(Pais_Origen_)
df
# Out:
#      Millas_Por_Galon  Cilindros  Pais_Origen  Peso_En_Libras  Desplazamiento  \
# 0                18.0          8          NaN            3504           307.0
# 1                15.0          8          NaN            3693           350.0
# 2                18.0          8          NaN            3436           318.0
# 3                16.0          8          NaN            3433           304.0
# 4                17.0          8          NaN            3449           302.0
# ..                ...        ...          ...             ...             ...
# 401              27.0          4          NaN            2790           140.0
# 402              44.0          4          NaN            2130            97.0
# 403              32.0          4          NaN            2295           135.0
# 404              28.0          4          NaN            2625           120.0
# 405              31.0          4          NaN            2720           119.0
#
# ...

# %%
def cambio(pais):
  if pais=="USA":
    else== 1
  if pais=="Europe":
    else == 2
  if pais=="Japan":
    else ==3
    return cambio

# %% [markdown]
# Para recodificar la variable "Pais_origen" (1,2.3) aplicando la función apply

# %%
df["Pais_Origen"]=df["Pais_Origen"].apply(lambda x:1 if x=="USA" else 2 )
df
# Out:
#      Millas_Por_Galon  Cilindros  Pais_Origen  Peso_En_Libras  Desplazamiento  \
# 0                18.0          8            1            3504           307.0
# 1                15.0          8            1            3693           350.0
# 2                18.0          8            1            3436           318.0
# 3                16.0          8            1            3433           304.0
# 4                17.0          8            1            3449           302.0
# ..                ...        ...          ...             ...             ...
# 401              27.0          4            1            2790           140.0
# 402              44.0          4            2            2130            97.0
# 403              32.0          4            1            2295           135.0
# 404              28.0          4            1            2625           120.0
# 405              31.0          4            1            2720           119.0
#
# ...

# %% [markdown]
# ## **EJERCICIO 2**

# %% [markdown]
# **Limpieza y tratamiento de las variables **

# %%
df
# Out:
#      Millas_Por_Galon  Cilindros  Pais_Origen  Peso_En_Libras  Desplazamiento  \
# 0                18.0          8            1            3504           307.0
# 1                15.0          8            1            3693           350.0
# 2                18.0          8            1            3436           318.0
# 3                16.0          8            1            3433           304.0
# 4                17.0          8            1            3449           302.0
# ..                ...        ...          ...             ...             ...
# 401              27.0          4            1            2790           140.0
# 402              44.0          4            2            2130            97.0
# 403              32.0          4            1            2295           135.0
# 404              28.0          4            1            2625           120.0
# 405              31.0          4            1            2720           119.0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 406 entries, 0 to 405
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Millas_Por_Galon   398 non-null    float64
#  1   Cilindros          406 non-null    int64
#  2   Pais_Origen        406 non-null    int64
#  3   Peso_En_Libras     406 non-null    int64
#  4   Desplazamiento     406 non-null    float64
#  5   Aceleracion        406 non-null    float64
#  6   Nombre             406 non-null    object
#  7   Anyo               406 non-null    object
#  8   Caballo_De_Fuerza  400 non-null    float64
# dtypes: float64(4), int64(3), object(2)
# memory usage: 28.7+ KB

# %%
df.isnull().sum()
# Out:
# Millas_Por_Galon     8
# Cilindros            0
# Pais_Origen          0
# Peso_En_Libras       0
# Desplazamiento       0
# Aceleracion          0
# Nombre               0
# Anyo                 0
# Caballo_De_Fuerza    6
# dtype: int64

# %%
pd.DataFrame(df.isna().sum(), 
             columns = ['Perdidos'])
# Out:
#                    Perdidos
# Millas_Por_Galon          8
# Cilindros                 0
# Pais_Origen               0
# Peso_En_Libras            0
# Desplazamiento            0
# Aceleracion               0
# Nombre                    0
# Anyo                      0
# Caballo_De_Fuerza         6

# %%
import statistics as stat

# %%
col_num = ["Millas_Por_Galon","Cilindros","Peso_En_Libras","Aceleracion","Desplazamiento","Caballo_De_Fuerza"]

df[col_num] = df[col_num].fillna(df[col_num].mean())  # imputamos con la mediana las variables numéricas

#df[col_str] = df[col_str].fillna(df[col_str].apply(moda))  # imputamos con la mediana las variables cualitativas

pd.DataFrame(df.isna().sum()/df.count()*100, columns = ['%Perdidos'])
# Out:
#                    %Perdidos
# Millas_Por_Galon         0.0
# Cilindros                0.0
# Pais_Origen              0.0
# Peso_En_Libras           0.0
# Desplazamiento           0.0
# Aceleracion              0.0
# Nombre                   0.0
# Anyo                     0.0
# Caballo_De_Fuerza        0.0

# %% [markdown]
# ***Generar 5 nuevas variables con los siguientes criterios***

# %%
def mio(df,col1,col2):
    return np.log10(df[col1]/df[col2])
df["nuevo1"]=mio(df,"Millas_Por_Galon","Cilindros")
df
# Out:
#      Millas_Por_Galon  Cilindros  Pais_Origen  Peso_En_Libras  Desplazamiento  \
# 0                18.0          8            1            3504           307.0
# 1                15.0          8            1            3693           350.0
# 2                18.0          8            1            3436           318.0
# 3                16.0          8            1            3433           304.0
# 4                17.0          8            1            3449           302.0
# ..                ...        ...          ...             ...             ...
# 401              27.0          4            1            2790           140.0
# 402              44.0          4            2            2130            97.0
# 403              32.0          4            1            2295           135.0
# 404              28.0          4            1            2625           120.0
# 405              31.0          4            1            2720           119.0
#
# ...

# %%
import math 
from math import exp
#math.exp(1)

# %%
def mio1(df,col1,col2):
    return np.sqrt(df[col1]*np.exp(df[col2])/100)
df["nuevo2"]=mio1(df,"Millas_Por_Galon","Cilindros")
df
# Out:
#      Millas_Por_Galon  Cilindros  Pais_Origen  Peso_En_Libras  Desplazamiento  \
# 0                18.0          8            1            3504           307.0
# 1                15.0          8            1            3693           350.0
# 2                18.0          8            1            3436           318.0
# 3                16.0          8            1            3433           304.0
# 4                17.0          8            1            3449           302.0
# ..                ...        ...          ...             ...             ...
# 401              27.0          4            1            2790           140.0
# 402              44.0          4            2            2130            97.0
# 403              32.0          4            1            2295           135.0
# 404              28.0          4            1            2625           120.0
# 405              31.0          4            1            2720           119.0
#
# ...

# %%
def mio3(df,col1,col2):
   mio2 = if (df[col1] > df[col2]):5
          else: 3
          return 
df["nuevo3"]=mio3(df,"Millas_Por_Galon","Cilindros")
df["nuevo3"]
# Out:
#   File "<ipython-input-53-9c86c604033c>", line 2
#     mio2 = if (df[col1] > df[col2]):5
#             ^
# SyntaxError: invalid syntax

# %%
def mio(df,col1,col2):
    return 1/np.log(df[col1]/df[col2])*100
df["nuevo3"]=mio(df,"Millas_Por_Galon","Cilindros")
df
# Out:
#      Millas_Por_Galon  Cilindros  Pais_Origen  Peso_En_Libras  Desplazamiento  \
# 0                18.0          8            1            3504           307.0
# 1                15.0          8            1            3693           350.0
# 2                18.0          8            1            3436           318.0
# 3                16.0          8            1            3433           304.0
# 4                17.0          8            1            3449           302.0
# ..                ...        ...          ...             ...             ...
# 401              27.0          4            1            2790           140.0
# 402              44.0          4            2            2130            97.0
# 403              32.0          4            1            2295           135.0
# 404              28.0          4            1            2625           120.0
# 405              31.0          4            1            2720           119.0
#
# ...

# %%
def mio(df,col1,col2):
    return df[col2**2]/df[col1]
df["nuevo4"]=mio(df,"Millas_Por_Galon","Cilindros")
df
# Out:
#   File "<ipython-input-49-a70b0ea8eb8c>", line 2
#     return pd.(df[col2**2]/df[col1])
#               ^
# SyntaxError: invalid syntax
